# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("/Users/saikarthik/Desktop/ml algorithms from scratch /feature engineering/mercedes-benz-greener-manufacturing/train.csv",usecols=["X1","X2","X3","X4","X5","X6"])

# %%
df.head()
# Out:
#   X1  X2 X3 X4 X5 X6
# 0  v  at  a  d  u  j
# 1  t  av  e  d  y  l
# 2  w   n  c  d  x  j
# 3  t   n  f  d  x  l
# 4  v   n  f  d  h  d

# %%
for i in df.columns :
    print(len(df[i].unique()))
# Out:
# 27
# 44
# 7
# 4
# 29
# 12

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#       X1_aa  X1_ab   X1_b   X1_c   X1_d   X1_e   X1_f   X1_g   X1_h   X1_i  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4204  False  False  False  False  False  False  False  False  False  False
# 4205  False  False  False  False  False  False  False  False  False  False
# 4206  False  False  False  False  False  False  False  False  False  False
# 4207  False  False  False  False  False  False  False  False  False  False
# 4208  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
pd.get_dummies(df,drop_first=True).shape
# Out:
# (4209, 117)

# %%
df["X2"].value_counts().sort_values(ascending=False).head(10)
# Out:
# X2
# as    1659
# ae     496
# ai     415
# m      367
# ak     265
# r      153
# n      137
# s       94
# f       87
# e       81
# Name: count, dtype: int64

# %%
top10=[df["X2"].value_counts().sort_values(ascending=False).head(10).index]

# %%
top10
# Out:
# [Index(['as', 'ae', 'ai', 'm', 'ak', 'r', 'n', 's', 'f', 'e'], dtype='object', name='X2')]

# %%
# Out:
# [Index(['as', 'ae', 'ai', 'm', 'ak', 'r', 'n', 's', 'f', 'e'], dtype='object', name='X2')]

# %%
for i in top10 :
    df[i]=np.where(df["X2"]==i,1,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 for i in top10 :
# ----> 2     df[i]=np.where(df["X2"]==i,1,0)
#
# File ~/tensorflow-test/env/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/tensorflow-test/env/lib/python3.8/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/tensorflow-test/env/lib/python3.8/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
