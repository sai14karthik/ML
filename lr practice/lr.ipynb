# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=( 12,6)
import seaborn as sns 
# %matplotlib inline

# %%
from sklearn import linear_model

# %%
df=pd.read_csv("/Users/saikarthik/Desktop/ml algorithms from scratch /simple linear regression implementation/canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.dtypes
# Out:
# year                         int64
# per capita income (US$)    float64
# dtype: object

# %%
df.shape
# Out:
# (47, 2)

# %%
plt.scatter(df["year"],df["per capita income (US$)"])
plt.xlabel("year")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
df.corr()
# Out:
#                              year  per capita income (US$)
# year                     1.000000                 0.943884
# per capita income (US$)  0.943884                 1.000000

# %%
sns.pairplot(df)
# Out:
# /Users/saikarthik/tensorflow-test/env/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df["per capita income (US$)"])
# Out:
# <Axes: ylabel='per capita income (US$)'>

# %%
sns.boxplot(df["year"])
# Out:
# <Axes: ylabel='year'>

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[["year"]]
y=df["per capita income (US$)"]

# %%
xtrain , xtest , ytrain,ytest = train_test_split(x,y, random_state=42,test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
xtrain=scaler.fit_transform(xtrain)

# %%
xtest=scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([822.5431161])

# %%
regression.intercept_
# Out:
# -1620384.422616578

# %%
plt.scatter (xtrain,ytrain)
plt.plot(xtrain, regression.predict(xtrain))

# %%
year = 1970
reshaped_year = np.array(year).reshape(1, -1)

prediction = regression.predict(reshaped_year)n
# Out:
# /Users/saikarthik/tensorflow-test/env/lib/python3.8/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([25.5161027])

# %%
def prediction(a) :
    a = np.array(a).reshape(1, -1)
    prediction = regression.predict(a)
    return a

# %%
prediction(1970)
# Out:
# /Users/saikarthik/tensorflow-test/env/lib/python3.8/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1970]])
